# %% [markdown]
# <a href="https://colab.research.google.com/github/Lajs5257/Professional-en-Data-Science-AI/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Proyecto Final del Curso de Data Science / AI
### Luis Alberto Jiménez Soto
## Industrias manufactureras

# %%
from jupyter_dash import JupyterDash # Versión de dash para notebooks
from dash import dcc # Componentes HTML preconstruidos para dashboards
from dash import html # Componentes HTML nativos
from dash.dependencies import Input, Output # Clases Input y Output
import plotly.express as px # Generar gráficas e importar datasets con Plotly

import pandas as pd # Recolección y manipulación de datos

# %% [markdown]
# ## Visualización de datos

# %%
#df = pd.read_csv('C:\\Users\\lajs5\\Downloads\\conjunto_de_datos\\denue_inegi_31-33_.csv', encoding="ISO-8859-1", low_memory=False)
#df.head()

import zipfile
with zipfile.ZipFile('./denue_00_31-33_1121_csv.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %%
df['fecha_alta'] = pd.to_datetime(df['fecha_alta'].astype(str), format='%Y-%m')
df['fecha_alta'] = pd.DatetimeIndex(df['fecha_alta']).year

# contar numero de empresas por industria
dfEmpresasEstadosAnios=df[['entidad','fecha_alta','id']].groupby(['entidad','fecha_alta']).count().reset_index()
#dfEmpresasEstadosAnios.head()
dfEmpresasAnios = df[['fecha_alta','id']].groupby(['fecha_alta']).count().reset_index()
dfEmpresasAnios.head()
# Out:
#    fecha_alta      id
# 0        2010  207036
# 1        2011     736
# 2        2012     967
# 3        2013     773
# 4        2014  125382

# %%
df['fecha_alta'] = pd.to_datetime(df['fecha_alta'].astype(str), format='%Y-%m')
df['fecha_alta'] = pd.DatetimeIndex(df['fecha_alta']).year
lista_year=df.sort_values("fecha_alta")["fecha_alta"].unique()
dataframe=pd.DataFrame(lista_year, columns=['fecha_alta'])
print (dataframe)
# crear un dataframe con los datos de 201
# Out:
#     fecha_alta
# 0         2010
# 1         2011
# 2         2012
# 3         2013
# 4         2014
# 5         2016
# 6         2017
# 7         2018
# 8         2019
# 9         2020
# 10        2021

# %% [markdown]
# Contamos con 2 tablas de interes:
# - conjunto_de_datos
# - diccionario_de_datos

# %%
# Conjunto de datos
dfConjuntoDatos = pd.read_csv('C:\\Users\\lajs5\\Downloads\\conjunto_de_datos\\denue_inegi_31-33_.csv', encoding="ISO-8859-1",dtype={'telefono': 'string'})
# Out:
# 0    4499168611
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
# Name: telefono, dtype: string

# %%
dfConjuntoDatos['telefono'].head()

# %%
# diccionario de datos
dfDiccionarioDatos = pd.read_csv('C:\\Users\\lajs5\\Downloads\\diccionario_de_datos\\denue_diccionario_de_datos.csv', encoding="ISO-8859-1")
dfDiccionarioDatos
# Out:
#    DICCIONARIO DE DATOS DENUE (15/06/2016)                  Unnamed: 1  \
# 0               Nombre del Atributo en csv  Nombre del Atributo en DBF
# 1                                       id                          id
# 2                                nom_estab                   nom_estab
# 3                               raz_social                  raz_social
# 4                               codigo_act                  codigo_act
# 5                               nombre_act                  nombre_act
# 6                                  per_ocu                     per_ocu
# 7                                tipo_vial                   tipo_vial
# 8                                 nom_vial                    nom_vial
# 9                               tipo_v_e_1                  tipo_v_e_1
# 10                               nom_v_e_1                   nom_v_e_1
# 11                              tipo_v_e_2                  tipo_v_e_2
# 12                               nom_v_e_2                   nom_v_e_2
# 13                              tipo_v_e_3                  tipo_v_e_3
# 14                               nom_v_e_3                   nom_v_e_3
# 15                              numero_ext                  numero_ext
# 16                               letra_ext                   letra_ext
# 17                                edificio                    edificio
# 18                              edificio_e                  edificio_e
# 19                              numero_int                  numero_int
# 20                               letra_int                   letra_int
# 21                              tipo_asent                  tipo_asent
# 22                              nomb_asent                  nomb_asent
# 23                              tipoCenCom                  tipoCenCom
# 24                              nom_CenCom                  nom_CenCom
# 25                               num_local                   num_local
# 26                              cod_postal                  cod_postal
# 27                                 cve_ent                     cve_ent
# 28                                 entidad                     entidad
# 29                                 cve_mun                     cve_mun
# 30                               municipio                   municipio
# 31                                 cve_loc                     cve_loc
# 32                               localidad                   localidad
# 33                                    ageb                        ageb
# 34                                 manzana                     manzana
# 35                                telefono                    telefono
# 36                              correoelec                  correoelec
# 37                                     www                         www
# 38                              tipoUniEco                  tipoUniEco
# 39                                 latitud                     latitud
# 40                                longitud                    longitud
# 41                              fecha_alta                  fecha_alta
#
#       Unnamed: 2 Unnamed: 3                                         Unnamed: 4
# 0   Tipo de dato   Longitud                                        Descripción
# 1       numérico         10  Número  de identificación del DENUE, es una cl...
# 2   alfanumérico        150  Es el nombre comercial o nombre exterior con e...
# 3   alfanumérico        150  Es la forma con que está legalmente constituid...
# 4   alfanumérico          6  La clasificación de las actividades desarrolla...
# 5   alfanumérico        250  Nombre del código de actividad conforme al SCI...
# 6   alfanumérico         20  Comprende al personal contratado directamente ...
# 7   alfanumérico         25  Es la superficie del terreno destinada para el...
# 8   alfanumérico        100  Es el sustantivo propio con el cual se identif...
# 9   alfanumérico         40  Es la superficie del terreno destinada para el...
# 10  alfanumérico        100  Es el sustantivo propio con el cual se identif...
# 11  alfanumérico         40  Es la superficie del terreno destinada para el...
# 12  alfanumérico        100  Es el sustantivo propio con el cual se identif...
# 13  alfanumérico         40  Es la superficie del terreno destinada para el...
# 14  alfanumérico        100  Es el sustantivo propio con el cual se identif...
# 15      numérico          7  Son los valores numéricos que identifican a un...
# 16  alfanumérico         35  Son los caracteres alfanuméricos que identific...
# 17  alfanumérico         35  Es el sustantivo propio con el que se identifi...
# 18  alfanumérico         35  Es con el que se identifica el piso o nivel de...
# 19      numérico          7  Son los valores numéricos que identifican el d...
# 20  alfanumérico         35  Son los caracteres alfanuméricos que identific...
# 21  alfanumérico         25  Es la clasificación que se da al asentamiento ...
# 22  alfanumérico         75  Es el sustantivo propio con el cual se identif...
# 23  alfanumérico         30  Tipo de plaza, centro comercial, etcétera dond...
# 24  alfanumérico         75  Nombre de la plaza, centro comercial, etcétera...
# 25  alfanumérico         35  Dato alfanumérico que corresponde al local en ...
# 26  alfanumérico          5  Clave numérica integrada por cinco dígitos est...
# 27  alfanumérico          2  Clave que identifica a la entidad federativa e...
# 28  alfanumérico         40  Es el sustantivo propio que identifica a la en...
# 29  alfanumérico          3  Clave que identifica al Municipio estadístico,...
# 30  alfanumérico        100  Es el sustantivo propio que identifica al Muni...
# 31  alfanumérico          4  Clave que identifica a la localidad estadístic...
# 32  alfanumérico        100  Es el sustantivo propio que identifica a la lo...
# 33  alfanumérico          4  Es la extensión territorial que corresponde a ...
# 34  alfanumérico          3  Clave geoestadística de la manzana, compuesta ...
# 35  alfanumérico         20  Número telefónico, secuencia de dígitos que pe...
# 36  alfanumérico         75  Correo electrónico, es la serie de caracteres ...
# 37  alfanumérico         75  Son los datos que permiten el acceso a informa...
# 38  alfanumérico          8  Grupo de categorías que sirve para identificar...
# 39      numérico         20  Es la distancia que existe entre la unidad eco...
# 40      numérico         20  Es la distancia que existe entre la unidad eco...
# 41  alfanumérico         15  Fecha en la que la unidad económica se integró...

# %%
from jupyter_dash import JupyterDash # Versión de dash para notebooks
from dash import dcc # Componentes HTML preconstruidos para dashboards
from dash import html # Componentes HTML nativos
from dash.dependencies import Input, Output # Clases Input y Output
import plotly.express as px # Generar gráficas e importar datasets con Plotly

import pandas as pd # Recolección y manipulación de datos
from dash import Dash
import plotly.graph_objects as go
import requests
import zipfile

with zipfile.ZipFile('./denue_00_31-33_1121_csv.zip', 'r') as zip_ref:
    zip_ref.extractall('./')
repo_url = 'https://raw.githubusercontent.com/angelnmara/geojson/master/mexicoHigh.json' 
#Archivo GeoJSON
mx_regions_geo = requests.get(repo_url).json()
app = Dash(__name__)

# cargamos nuestro conjunto de datos
dfDatos = pd.read_csv('./conjunto_de_datos/denue_inegi_31-33_.csv', encoding="ISO-8859-1",dtype={'telefono': 'string'})
# ahora convertimos la columna fecha_alta a tipo fecha en años para facilitar el filtrado
dfDatos['fecha_alta'] = pd.to_datetime(dfDatos['fecha_alta'].astype(str), format='%Y-%m')
dfDatos['fecha_alta'] = pd.DatetimeIndex(dfDatos['fecha_alta']).year

# ahora filtramos el conjunto de datos para obtener todos años
lista_year = dfDatos.sort_values("fecha_alta")["fecha_alta"].unique()
data_year=pd.DataFrame(lista_year, columns=['fecha_alta'])

# ahora filtramos el conjunto de datos para obtener todos los estados
dfEmpresasEstadosAnios=dfDatos[['entidad','fecha_alta','id']].groupby(['entidad','fecha_alta']).count().reset_index()
dfEmpresasAnios = dfDatos[['fecha_alta','id']].groupby(['fecha_alta']).count().reset_index()
# empresas creadas por año
fig2 = px.bar(dfEmpresasAnios, x="fecha_alta", y="id", title="Empresas por año")

fig3 = px.line(dfEmpresasEstadosAnios, x="fecha_alta", y="id", color='entidad', title="Empresas por año y estado")

# creamos nuestro dashboard
app.layout = html.Div([
    html.H1("Industrias manufactureras"),
    html.P("Desde julio de 2010 el Instituto Nacional de Estadística y Geografía ha puesto a disposición de la sociedad el Directorio Estadístico Nacional de Unidades Económicas (DENUE) con in- formación de los negocios activos del país. Los datos que propor- ciona el DENUE permiten identificar a las unidades económicas por el nombre comercial, el tipo de organización jurídica (personas físicas o morales), por su actividad económica y por su tamaño (con base en el estrato de personal ocupado); así como, ubicarlas en el territorio mexicano por regiones, localidades, manzanas y calles. El Directorio también provee las coordenadas geográficas de la ubicación de los establecimientos para que puedan ser visualizados en la cartografía digital o en imágenes satelitales."),
    html.H2("¿Por qué se eligió este conjunto de datos?"),
    html.P("El conjunto de datos que se eligió para este proyecto es el de las industrias manufactureras, ya que es un sector que ha crecido en los últimos años y que ha generado muchos empleos en el país, por lo que es importante conocer el comportamiento de este sector en el país."),
    html.P("Así mismo, el poder ver como esta pandemia afecto en la creación de nuevas empresas en el país, ya que se puede ver que en el año 2020 hubo una disminución en la creación de nuevas empresas, lo que puede ser un indicador de que la pandemia afecto a este sector."),
    html.H2("¿Comó se comporto la creación de nuevas empresas en el país por año?"),
    dcc.Graph(figure=fig2),
    html.H2("¿Comó se comporto la creación de nuevas empresas en el país por año y por estado?"),
    html.Div([
        html.Label("Año"),
        dcc.Dropdown(data_year['fecha_alta'], id='year', placeholder='Selecciona un año',value=2010),
    ]),
    dcc.Graph(id="graph"),
    dcc.Graph(figure=fig3),
    
])


@app.callback(
    Output("graph", "figure"),
    Input("year", "value"))
    
def update_figure(year):    
    dfEEA=dfEmpresasEstadosAnios.query(f'fecha_alta == {year}')
    fig = px.choropleth(data_frame=dfEEA, 
                        geojson=mx_regions_geo, 
                        locations=dfEEA['entidad'], # nombre de la columna del Dataframe
                        featureidkey='properties.name',  # ruta al campo del archivo GeoJSON con el que se hará la relación (nombre de los estados)
                        color=dfEEA['id'], #El color depende de las cantidades
                        color_continuous_scale="burg",
                        scope="north america"
                    )

    fig.update_geos(showcountries=True, showcoastlines=True, showland=True, fitbounds="locations")
    return fig


app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Oct/2022 18:26:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2022 18:26:45] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2022 18:26:45] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2022 18:26:45] "GET /_favicon.ico?v=2.6.2 HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2022 18:26:45] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2022 18:26:45] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [13/Oct/2022 18:26:45] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2022 18:26:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Oct/2022 18:26:55] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]
