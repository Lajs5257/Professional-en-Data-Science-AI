# %% [markdown]
# <a href="https://colab.research.google.com/github/Lajs5257/Professional-en-Data-Science-AI/blob/main/Challenge_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge (3/8): Datos abiertos del Instituto Nacional de Estadística y Geografía (INEGI)
#
# Dani, lograste dominar esas gráficas para datos numéricos como nadie.
# ¡Estás cada vez más cerca de completar el reto del INEGI!
# En el reto anterior lograste representar gráficamente lo siguiente:
# 1. La distribución de tus datos numéricos.
# 2. La dispersión de un par de variables numéricas.
# 3. La representación de una variable numérica mediante una serie de tiempo.
#
# Siguiendo la dinámica del reto anterior, ahora toca explorar nuestra variables categóricas.
#
# IMPORTANTE: Toma en cuenta las preguntas que planteaste en el primer reto para identificar aquellas que podrían ser respondidas con las gráficas vistas en clase.

# %% [markdown]
# CONSEJO: Con variables categóricas, lo más probable es que quieras realizar gráficas de comparación y composición. Te dejamos la siguiente imagen como guía para checar qué gráficas puedes realizar:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. Gráficas de comparación
# Recuerda que este tipo de gráficas nos sirven en los casos donde tenemos dos o más variables categóricas cuyos valores queremos comparar a través del tiempo o bien, agrupadas por una variable categórica extra.

# %% [markdown]
# Completa las siguientes tareas:
# 1. Identifica si alguna de las preguntas que planteaste en el primer reto pueden explorarse con una comparación. Si no tienes alguna ¡Es buen momento para formularla!
# 2. Con ayuda de la imagen guía mostrada más arriba elige la gráfica adecuada para cada pregunta que hayas identificado.

# %% [markdown]
# ## 2. Gráficas de composición
# La composición, por su parte, nos permite observar qué tanto le corresponde a una o más variables categóricas, de un total global, que bien puede ser representado en unidades o en porcentaje.

# %% [markdown]
# Completa las siguientes tareas:
# 1. Identifica si alguna de las preguntas que planteaste en el primer reto pueden explorarse con una composición. Si no tienes alguna ¡Es buen momento para formularla!
# 2. Con ayuda de la imagen guía mostrada más arriba elige la gráfica adecuada para cada pregunta que hayas identificado.
